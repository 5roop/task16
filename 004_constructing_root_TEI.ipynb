# %%
from typing import Union, List
from pathlib import Path
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

mpdf = pd.read_pickle("mpdf_corrected.pickle")
mpdf["party"] = mpdf.party.fillna("NEZAVISNI")
partiesdf = pd.read_pickle("partiesdf_corrected.pickle")
termdata = pd.read_csv("../SRB/terms.csv").set_index("Term").astype(str)

def transform_abbreviation(s: str) -> str:
    return f"party.{s.replace(' ', '_').upper().replace('!', '')}"



from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# Fix missing dates where we have years available:

# %%
c = ( mpdf.date_of_birth == "-" )& (~mpdf.year_of_birth.isna()) & (~(mpdf.year_of_birth == "-"))
mpdf.loc[c, "date_of_birth"] = mpdf.year_of_birth[c]

# %% [markdown]
# Let's see which parties have non-trivial names:

# %%
gb = partiesdf.groupby("party").agg({
    "full_name": lambda l: len(set(l)),
    # "full_name": set
})
problematic_abbreviations = gb[gb.full_name != 1].index.values
problematic_abbreviations

gb = partiesdf[partiesdf.party.isin(problematic_abbreviations)].groupby("party").agg({
    "full_name": set,
})
gb
# Out:
#                                                                                             full_name
# party
# BS                                                                      {Bogata Srbija, Bolja Srbija}
# DHSS                                   {Demohrišćanska stranka Srbije, Demohrišćanska Stranka Srbije}
# LS                                                               {Liga za Šumadiju, Lista za Sandžak}
# PS                                                           {Pokret socilalista, Pokret socijalista}
# SDP    {Sandžačka demokratska partija, Socijaldemokratska partija Srbije, Socijaldemokratska partija}

# %% [markdown]
# # Recipe:
#
# * `Demohrišćanska Stranka Srbije` -> `Demohrišćanska stranka Srbije` in accordance with Wikipedia.
# * `Pokret socilalista` -> `Pokret socialista`, seems a human error.
# * `Socijaldemokratska partija` -> `Socijaldemokratska partija Srbije`, in accordance with Wikipedia. The abbreviation to be changed to SDPS in accordance with Wikipedia. There is no extant party with SDPS abbreviation. `Sandžačka demokratska partija` can remain abbreviated SDP.
# * `Liga za Šumadiju` to be assigned LŠ, `Lista za Sandžak` to be left LS
# * `Bogata Srbija` to be assigned BogS, `Bolja Srbija` preserves BS
#
# While this is easily done in parties table, but for MPs we have no party affiliation other than the abbreviation. This will have to be done manually for parties BS, LS, SDP.

# %%
partiesdf["full_name"] = partiesdf.full_name.replace({
    "Demohrišćanska Stranka Srbije": "Demohrišćanska stranka Srbije",
    "Pokret socilalista": "Pokret socijalista",
    "Socijaldemokratska partija": "Socijaldemokratska partija Srbije"
})

partiesdf.loc[partiesdf.full_name == "Liga za Šumadiju", "party"] = "LŠ"
partiesdf.loc[partiesdf.full_name == "Bogata Srbija", "party"] = "BogS"
partiesdf.loc[partiesdf.full_name == "Socijaldemokratska partija Srbije", "party"] = "SDPS"

# %%
# Inspection:
# mpdf[mpdf.party.isin(["BS", "LS", "SDP"])]

mpdf.loc[[4,218,215,231], "party"] = "LŠ"
mpdf.loc[[608, 653,  662, 919,940,1138,1183, 1215,1322,1357,1415, 1439, 1445, 1459,1464,1498, 1556, 1644, 1729,1735, 1746, 1757, 1760, 1770,1786,1815,1942,1952,1964,1969,2010,2015,2023,2031,2041,2066,2186,2238,2248,2257,2304,2306,2414,2428], "party"] = "SDPS"
mpdf.loc[[1593], "party"] = "BogS"

# %%
from xml.etree.ElementTree import Element, SubElement, tostring, XML, parse
from xml.dom import minidom
def pretty_print(s) -> None:
    print(minidom.parseString(tostring(s).decode("utf")).toprettyxml("\t"))
def pretty_string(s) -> None:
    return minidom.parseString(tostring(s).decode("utf")).toprettyxml("\t")

# %% [markdown]
# # Terms (line 438):
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/org[2]/listEvent`

# %%
listEvent = Element("listEvent")
head = SubElement(listEvent, "head")
head.set("xml:lang", "sr")
head.text = "Mandatno obdoblje"
head = SubElement(listEvent, "head")
head.set("xml:lang", "en")
head.text = "Legislative period"

for i, row in termdata.iterrows():
    event = SubElement(listEvent, "event")
    event.set("xml:id", f"NS.{i}")
    event.set("from", row["From"])
    to = row["To"]
    if not pd.isna(to):
        event.set("to", row["To"])
    
    label = SubElement(event, "label")
    label.set("xml:lang", "sr")
    label.text = f"{int(i)}. saziv"
    label = SubElement(event, "label")
    label.set("xml:lang", "en")
    label.text = f"Term {int(i)}"
listEvent_str = pretty_string(listEvent)
listEvent_str = "\n".join(listEvent_str.split("\n")[1:])
print(listEvent_str)
# Out:
# <listEvent>
# 	<head xml:lang="sr">Mandatno obdoblje</head>
# 	<head xml:lang="en">Legislative period</head>
# 	<event xml:id="NS.4" from="19971203" to="20010121">
# 		<label xml:lang="sr">4. saziv</label>
# 		<label xml:lang="en">Term 4</label>
# 	</event>
# 	<event xml:id="NS.5" from="20010122" to="20040126">
# 		<label xml:lang="sr">5. saziv</label>
# 		<label xml:lang="en">Term 5</label>
# 	</event>
# 	<event xml:id="NS.6" from="20040127" to="20070213">
# 		<label xml:lang="sr">6. saziv</label>
# 		<label xml:lang="en">Term 6</label>
# 	</event>
# 	<event xml:id="NS.7" from="20070214" to="20080610">
# 		<label xml:lang="sr">7. saziv</label>
# 		<label xml:lang="en">Term 7</label>
# 	</event>
# 	<event xml:id="NS.8" from="20080611" to="20120530">
# 		<label xml:lang="sr">8. saziv</label>
# 		<label xml:lang="en">Term 8</label>
# 	</event>
# 	<event xml:id="NS.9" from="20120531" to="20140415">
# 		<label xml:lang="sr">9. saziv</label>
# 		<label xml:lang="en">Term 9</label>
# 	</event>
# 	<event xml:id="NS.10" from="20140416" to="20160603">
# 		<label xml:lang="sr">10. saziv</label>
# 		<label xml:lang="en">Term 10</label>
# 	</event>
# 	<event xml:id="NS.11" from="20160603" to="20220802">
# 		<label xml:lang="sr">11. saziv</label>
# 		<label xml:lang="en">Term 11</label>
# 	</event>
# 	<event xml:id="NS.12" from="20200803" to="20220731">
# 		<label xml:lang="sr">12. saziv</label>
# 		<label xml:lang="en">Term 12</label>
# 	</event>
# </listEvent>

# %% [markdown]
# # Parties: line 447
#
# path:
# `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/org[3:]`

# %%
partiesdf["id"] = partiesdf.party.apply(transform_abbreviation)

partydata = partiesdf["party full_name id".split()].drop_duplicates()

orgs = []
for i, row in partydata.iterrows():
    org = Element("org")
    org.set("xml:id", row["id"])
    org.set("role", "parliamentaryGroup")
    orgName = SubElement(org, "orgName")
    orgName.set("full", "yes")
    orgName.set("xml:lang", "sr")
    orgName.text = row["full_name"]
    
    orgName = SubElement(org, "orgName")
    orgName.set("full", "abb")
    orgName.text = row["party"]
    orgs.append(org)
    
# Add nezavisni:
org = Element("org")
org.set("xml:id", "party.NEZAVISNI")
org.set("role", "parliamentaryGroup")
orgName = SubElement(org, "orgName")
orgName.set("full", "yes")
orgName.set("xml:lang", "sr")
orgName.text = "nezavisni"
orgName = SubElement(org, "orgName")
orgName.set("full", "abb")
orgName.text = "nezavisni"
orgs.append(org)

orgs = [pretty_string(i) for i in orgs]

orgstring = "\n".join(
    ["\n".join(org.split("\n")[1:])for org in orgs]
)
# print(orgstring)

# %% [markdown]
# # People: line 525
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listPerson`

# %%
listPerson = []
codemps = mpdf.codemp.drop_duplicates()
n = 0

from utils import drop_punctuation
for i, c in enumerate(codemps):    
    subset = mpdf.query(f"codemp=='{c}'").reset_index(drop=True)
    surname = subset.lastname[0]
    forename = subset.firstname[0]
    sex = "M" if subset.gender[0] == 0 else "F"
    birth = str(subset.date_of_birth[0])
    try:
        birth = f"{birth[0:4]}-{birth[4:6]}-{birth[-2:]}"
    except:
        pass
    reference_name = f"{surname.replace(' ', '')}{forename.replace(' ', '')}"
    reference_name = drop_punctuation(reference_name)
    
    person = Element("person")
    person.set("xml:id", reference_name)
    person.set("n", str(c))
    n += 1
    persName = SubElement(person, "persName")
    
    buf = SubElement(persName, "surname")
    buf.text = surname
    
    buf = SubElement(persName, "forename")
    buf.text = forename
    
    buf = SubElement(person, "sex")
    buf.set("value", sex)
    try:
        int(birth) # This will trip if date isn't a numeric string
        buf = SubElement(person, "birth")
        buf.set("when", birth)
    except:
        pass
    

    for i, row in subset.drop_duplicates().iterrows():  
        term = row["term2"]
        fromto = termdata.loc[term, :]
        aff = SubElement(person, "affiliation")
        aff.set("role", "member")
        aff.set("ref", f"#{transform_abbreviation(row['party'])}")
        aff.set("from", fromto.From)
        if not pd.isna(fromto.To):
            aff.set("to", fromto.To)
        
        rolename = SubElement(aff, "roleName")
        rolename.set("xml:lang", "en")
        rolename.text = "Member"

        aff = SubElement(person, "affiliation")
        aff.set("role", "member")
        aff.set("ref", "#NS")
        aff.set("ana", f"#NS.{row['term2']}")
        aff.set("from", fromto.From)
        if not pd.isna(fromto.To):
            aff.set("to", fromto.To)
        rolename = SubElement(aff, "roleName")
        rolename.set("xml:lang", "en")
        rolename.text = "MP"
    listPerson.append(person)

# # Add Unknown to listPersons:
# reference_name = "Unknown"
# person = Element("person")
# person.set("xml:id", reference_name)
# person.set("n", str(n))
# n += 1
# persName = SubElement(person, "persName")
# buf = SubElement(persName, "surname")
# buf.text = "Unknown"
# buf = SubElement(persName, "forename")
# buf.text = "Unknown"
# listPerson.append(person)

# # Add Marina to listPersons
# reference_name = "MatulovićDropulićMarina"
# person = Element("person")
# person.set("xml:id", reference_name)
# person.set("n", str(n))
# n += 1
# persName = SubElement(person, "persName")
# buf = SubElement(persName, "surname")
# buf.text = "Matulović Dropulić"
# buf = SubElement(persName, "forename")
# buf.text = "Marina"
# buf = SubElement(person, "sex")
# buf.set("value", "F")
# listPerson.append(person)

# %%
listPerson = ["\n".join(pretty_string(p).split("\n")[1:]) for p in listPerson]
listPerson = "\n".join(listPerson)

# %%
path_to_term_tmxs = Path("/home/rupnik/parlamint/SRB/S/")
assert path_to_term_tmxs.exists()


xiincludes = ""
for file in sorted(list(path_to_term_tmxs.glob("ParlaMint-RS_T*.xml"))):
    xiincludes += f"""    <xi:include xmlns:xi="http://www.w3.org/2001/XInclude" href="{file.name}"/>\n"""

# %% [markdown]
# # Relations
#
# path: `/teiCorpus/teiHeader/profileDesc/particDesc/listOrg/listRelation`

# %%
# gb = partiesdf.groupby(["term2", "coalition"]).agg(
#     {
#         "id": lambda l: " ".join(set(["#"+i for i in l]))
#     }
# )
partiesdf["coalition"] = partiesdf.coalition.astype(str)
gb = partiesdf.groupby(["term2", "coalition"]).agg(
    {
        "id": lambda l: " ".join(set(["#"+i for i in l if i in partydata.id.values
                                      ]))
    }
)
terms = partiesdf.term2.unique()
listRelation = ""
for term in terms:
    if term > mpdf.term2.max():
        continue
    fromto = termdata.loc[term, :]
    ind = (term, "1")
    coalition = gb.loc[ind].id
    ind = (term, "0")
    opposition = gb.loc[ind].id
    listRelation += f"""
    <relation name="coalition"
            mutual="{coalition}"
            from="{fromto.From}"
            {'to="'+fromto.To+'"' if not pd.isna(fromto.To) else ""}
            ana="#NS.{term}"/>
    <relation name="opposition"
            active="{opposition}"
            passive="#government.RS"
            from="{fromto.From}"
            {'to="'+fromto.To+'"' if not pd.isna(fromto.To) else ""}
            ana="#NS.{term}"/>\n"""

# %% [markdown]
# # Counting extents and tagUsages

# %%
from typing import Union
from pathlib import Path
def get_extent(path: Union[str, Path]):
    if isinstance(path, Path):
        assert path.exists()
        path = str(path)
    namespace= {
        "n": "http://www.tei-c.org/ns/1.0",
        
    }
    termtei = parse(path)
    measures = termtei.getroot().findall(".//n:measure", namespaces=namespace)
    for i in measures:
        if i.get("unit") == "speeches":
            speeches = i.get("quantity")
        if i.get("unit") == "words":
            words = i.get("quantity")
    return {"words": int(words), "speeches": int(speeches)}

def get_tagusage(path: Union[str, Path]):
    if isinstance(path, Path):
        assert path.exists()
        path = str(path)
    namespace= {
        "n": "http://www.tei-c.org/ns/1.0",
        
    }
    termtei = parse(path)
    tagusages = termtei.getroot().findall(".//n:tagUsage", namespaces=namespace)
    for i in tagusages:
        if i.get("unit") == "speeches":
            speeches = i.get("quantity")
        if i.get("unit") == "words":
            words = i.get("quantity")
    return {i.get("gi"): i.get("occurs") for i in tagusages}

path_to_term_tmxs = Path("/home/rupnik/parlamint/SRB/S/")
assert path_to_term_tmxs.exists()


extents = []
tagusages = []
for file in sorted(list(path_to_term_tmxs.glob("ParlaMint-RS_T*.xml"))):
    extents.append(get_extent(file))
    tagusages.append(get_tagusage(file))
tus = pd.DataFrame(data=tagusages).astype(int)

tagusage = ""
for gi, occurs in tus.sum().items():
    tagusage += f"""<tagUsage gi="{gi}" occurs="{int(occurs)}"/>\n"""
extent_count = pd.DataFrame(data=extents).astype(int).sum()
words = extent_count["words"]
speeches = extent_count["speeches"]
extent = f"""<measure unit="speeches" quantity="{speeches}" xml:lang="sr">{f'{speeches:,d}'.replace(',','.')} govora</measure>
<measure unit="speeches" quantity="{speeches}" xml:lang="en">{speeches:,d} speeches</measure>
<measure unit="words" quantity="{words}" xml:lang="sr">{f'{words:,d}'.replace(',','.')} reči</measure>
<measure unit="words" quantity="{words}" xml:lang="en">{words:,d} words</measure>
"""

# %% [markdown]
# # Putting it all together

# %%
with open("/home/rupnik/parlamint/SRB/ParlaMint-RS_template.xml") as f:
    content = f.read()
from string import Template
template = Template(content)
filled_in = template.substitute(
    listEvent=listEvent_str,
    orgs=orgstring,
    listPerson=listPerson,
    xiincludes=xiincludes,
    listRelation=listRelation,
    extent=extent,
    tagusage=tagusage
)

with open("/home/rupnik/parlamint/SRB/ParlaMint-RS.xml", "w") as f:
    f.write(
        filled_in
    )

# %%
# %%bash
# pwd
# Out:
# /home/rupnik/parlamint/task16

# %%
# %%bash
#
# mkdir ~/parlamint/ParlaMint/Data/ParlaMint-RS
#
# cp ~/parlamint/SRB/S/* ~/parlamint/ParlaMint/Data/ParlaMint-RS/
# cp ~/parlamint/SRB/ParlaMint-RS.xml ~/parlamint/ParlaMint/Data/ParlaMint-RS/
#
#
# cd /home/rupnik/parlamint/ParlaMint
#
# # Validation
# make add-common-content-RS
# cd Data/ParlaMint-RS/
# cp add-common-content/* .
# rm -r add-common-content
# Out:
# rm -rf Data/ParlaMint-RS/add-common-content
# mkdir -p Data/ParlaMint-RS/add-common-content
# java -jar /usr/share/java/saxon.jar outDir=Data/ParlaMint-RS/add-common-content \
#    -xsl:Scripts/parlamint-add-common-content.xsl \
#    Data/ParlaMint-RS/ParlaMint-RS.ana.xml || :
# java -jar /usr/share/java/saxon.jar outDir=Data/ParlaMint-RS/add-common-content \
#    anaDir=`pwd`/Data/ParlaMint-RS/add-common-content/ParlaMint-RS \
#    -xsl:Scripts/parlamint-add-common-content.xsl \
#    Data/ParlaMint-RS/ParlaMint-RS.xml || :
# for component in `echo Data/ParlaMint-RS/ParlaMint-RS.ana.xml| xargs -I % java -cp /usr/share/java/saxon.jar net.sf.saxon.Query -xi:off \!method=adaptive -qs:'//*[local-name()="teiHeader"]//*[local-name()="include"]/@href' -s:% |sed 's/^ *href="//;s/"//'`; do \
#   echo "copying header component: Data/ParlaMint-RS/${component}" ; \
#     cp Data/ParlaMint-RS/${component} Data/ParlaMint-RS/add-common-content/ParlaMint-RS; \
# done;
# echo "Result is in: Data/ParlaMint-RS/add-common-content/ParlaMint-RS"
# Result is in: Data/ParlaMint-RS/add-common-content/ParlaMint-RS
# mkdir: cannot create directory ‘/home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS’: File exists
# Source file Data/ParlaMint-RS/ParlaMint-RS.ana.xml does not exist
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T04_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S-.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T05_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S-.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_S9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sp2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T06_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T07_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sp7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Spp.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T08_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S-.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_S9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sp8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Spp.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T09_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S-.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_S9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sp6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T10_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S-.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_S9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp20.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp21.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp23.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp24.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp25.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp26.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp27.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp28.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sp9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv20.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv21.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv22.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv23.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv24.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv25.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv26.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv27.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T11_Sv9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S15.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_S9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp01.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp02.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp03.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp04.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp05.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp06.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp07.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp08.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp09.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sp9.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv1.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv10.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv11.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv12.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv13.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv14.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv16.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv17.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv18.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv19.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv2.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv3.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv4.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv5.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv6.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv7.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv8.ana.xml
# ERROR : cannot locate .ana file /home/rupnik/parlamint/ParlaMint/Data/ParlaMint-RS/add-common-content/ParlaMint-RS/ParlaMint-RS_T12_Sv9.ana.xml
# INFO: Starting to process ParlaMint-SR
# INFO: Processing ParlaMint-RS_T04_S1.xml
# FATAL : BAD COUNTRY!
# Error on line 142 column 66 of parlamint-add-common-content.xsl:
#   XTMM9000  Processing terminated by xsl:message at line 142 in parlamint-add-common-content.xsl
# at variable houses on line 50 of parlamint-add-common-content.xsl:
#      invoked by global variable houses at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#50
# at variable house-refs on line 147 of parlamint-add-common-content.xsl:
#      invoked by global variable house-refs at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#147
#   In template rule with match="element(Q{http://www.tei-c.org/ns/1.0}meeting)" on line 604 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#366
#   In template rule with match="element(Q{http://www.tei-c.org/ns/1.0}meeting)" on line 365 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#297
#   In template rule with match="*" on line 292 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#297
#   In template rule with match="*" on line 292 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#297
#   In template rule with match="*" on line 292 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#297
#   In template rule with match="*" on line 292 of parlamint-add-common-content.xsl
#      invoked by xsl:apply-templates at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#279
#      invoked by xsl:for-each at file:/home/rupnik/parlamint/ParlaMint/Scripts/parlamint-add-common-content.xsl#275
#   In template rule with match="/" on line 272 of parlamint-add-common-content.xsl
# Processing terminated by xsl:message at line 142 in parlamint-add-common-content.xsl
# Source file Data/ParlaMint-RS/ParlaMint-RS.ana.xml does not exist
# cp: -r not specified; omitting directory 'add-common-content/ParlaMint-RS'

# %%
# %%bash
# cd /home/rupnik/parlamint/ParlaMint
# make validate-parlamint-RS

# %% [markdown]
# # Notes on the output:

# %% [markdown]
# # Adding missing persons:

# %%
f = "008_validation_out"
with open(f) as f:
    content = f.readlines()

pattern = '''{begining}find local id for u/@who="#{name}"\n'''
from parse import compile
p = compile(pattern)

missing = set()
for line in content:
    result = p.parse(line)
    try:
        missing.add(result["name"])
    except:
        continue
missing

# %%
# Out:
#     codemp  order_id      term1  term2  term_id type_of_list  \
# 30      M6        31  1997-2000      4       31      various
# 106     M7       107  1997-2000      4      107      various
# 538     M7       539  2003-2007      6       18       normal
#
#                  fullname   firstname  lastname party date_of_birth  \
# 30   Đorđević, Aleksandar  Aleksandar  Đorđević   SRS             -
# 106  Đorđević, Aleksandar  Aleksandar  Đorđević   SRS             -
# 538  Đorđević, Aleksandar  Aleksandar  Đorđević   SRS      19590820
#
#     year_of_birth  gender place_of_birth field_of_study education_y  \
# 30           1950       0              -              -          16
# 106          1950       0        Beograd              2          16
# 538          1959       0              -              -          16
#
#         bp_lat    bp_lon
# 30           -         -
# 106  44.688045  20.22171
# 538          -         -
